# %%
import torch
import torch.nn as nn
from torchvision.models.video import r2plus1d_18, R2Plus1D_18_Weights

# %%
backbone = r2plus1d_18(weights=R2Plus1D_18_Weights.KINETICS400_V1)
# Out:
# Downloading: "https://download.pytorch.org/models/r2plus1d_18-91a641e6.pth" to /Users/nhatminhnguyen/.cache/torch/hub/checkpoints/r2plus1d_18-91a641e6.pth
# 100%|██████████| 120M/120M [01:39<00:00, 1.27MB/s]

# %%
total_param = len(list(backbone.children()))

# %%
for i, child in enumerate(backbone.children()):
    print(f"type {i}: {child.type}")
# Out:
# type 0: <bound method Module.type of R2Plus1dStem(
#   (0): Conv3d(3, 45, kernel_size=(1, 7, 7), stride=(1, 2, 2), padding=(0, 3, 3), bias=False)
#   (1): BatchNorm3d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): Conv3d(45, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#   (4): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU(inplace=True)
# )>
# type 1: <bound method Module.type of Sequential(
#   (0): BasicBlock(
#     (conv1): Sequential(
#       (0): Conv2Plus1D(
#         (0): Conv3d(64, 144, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (1): BatchNorm3d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv3d(144, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
# ...
